# %%
# importing pandas
import pandas as pd
# importing numpy
import numpy as np

# %%
# importing OneHotEncoder
from sklearn.preprocessing import OneHotEncoder

# %%
# reading dataset
df = pd.read_csv(r'C:\Users\LENOVO\Projects\Feature-Engineering\train.csv')
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
# checking features
categorical_features= df.select_dtypes(include='O').keys()
# display categorical_features
categorical_features
# Out:
# Index(['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities',
#        'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
#        'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st',
#        'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation',
#        'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
#        'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual',
#        'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature',
#        'SaleType', 'SaleCondition'],
#       dtype='object')

# %%
# creating new df
# setting columns we use
new_df = pd.read_csv((r'C:\Users\LENOVO\Projects\Feature-Engineering\train.csv'),usecols=['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities',
       'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
       'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st',
       'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation',
       'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
       'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual',
       'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual',
       'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature',
       'SaleType', 'SaleCondition']) 
new_df.head()
# Out:
#   MSZoning Street Alley LotShape LandContour Utilities LotConfig LandSlope  \
# 0       RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1       RL   Pave   NaN      Reg         Lvl    AllPub       FR2       Gtl
# 2       RL   Pave   NaN      IR1         Lvl    AllPub    Inside       Gtl
# 3       RL   Pave   NaN      IR1         Lvl    AllPub    Corner       Gtl
# 4       RL   Pave   NaN      IR1         Lvl    AllPub       FR2       Gtl
#
#   Neighborhood Condition1  ... GarageType GarageFinish GarageQual GarageCond  \
# 0      CollgCr       Norm  ...     Attchd          RFn         TA         TA
# 1      Veenker      Feedr  ...     Attchd          RFn         TA         TA
# 2      CollgCr       Norm  ...     Attchd          RFn         TA         TA
# 3      Crawfor       Norm  ...     Detchd          Unf         TA         TA
# 4      NoRidge       Norm  ...     Attchd          RFn         TA         TA
#
# ...

# %%
#Let's see how many categories does each feature have
for feature in new_df.columns:
    print(feature , ':' ,len(new_df[feature].unique()) , 'category')
# Out:
# MSZoning : 5 category
# Street : 2 category
# Alley : 3 category
# LotShape : 4 category
# LandContour : 4 category
# Utilities : 2 category
# LotConfig : 5 category
# LandSlope : 3 category
# Neighborhood : 25 category
# Condition1 : 9 category
# Condition2 : 8 category
# BldgType : 5 category
# HouseStyle : 8 category
# RoofStyle : 6 category
# RoofMatl : 8 category
# Exterior1st : 15 category
# Exterior2nd : 16 category
# MasVnrType : 4 category
# ExterQual : 4 category
# ExterCond : 5 category
# Foundation : 6 category
# BsmtQual : 5 category
# BsmtCond : 5 category
# BsmtExposure : 5 category
# BsmtFinType1 : 7 category
# BsmtFinType2 : 7 category
# Heating : 6 category
# HeatingQC : 5 category
# CentralAir : 2 category
# Electrical : 6 category
# KitchenQual : 4 category
# Functional : 7 category
# FireplaceQu : 6 category
# GarageType : 7 category
# GarageFinish : 4 category
# GarageQual : 6 category
# GarageCond : 6 category
# PavedDrive : 3 category
# PoolQC : 4 category
# ...

# %%
#lets examine how many number of features,we will obtain after applying onehotencoding
pd.get_dummies(new_df,drop_first=True).shape
# Out:
# (1460, 208)

# %%
#Let's find the top 10 frequent categories in the feature - Neighborhood
new_df.Neighborhood.value_counts().sort_values(ascending=False).head(10)
# Out:
# Neighborhood
# NAmes      225
# CollgCr    150
# OldTown    113
# Edwards    100
# Somerst     86
# Gilbert     79
# NridgHt     77
# Sawyer      74
# NWAmes      73
# SawyerW     59
# Name: count, dtype: int64

# %%
#Let's make list with most frequent categories in the feature - Neighborhood
top_10= [i for i in new_df.Neighborhood.value_counts().sort_values(ascending=False).head(10).index]
top_10
# Out:
# ['NAmes',
#  'CollgCr',
#  'OldTown',
#  'Edwards',
#  'Somerst',
#  'Gilbert',
#  'NridgHt',
#  'Sawyer',
#  'NWAmes',
#  'SawyerW']

# %%
for label in top_10:
    new_df[label] = np.where(new_df['Neighborhood']==label, 1, 0)

new_df[['Neighborhood']+top_10].head(10)
# Out:
#   Neighborhood  NAmes  CollgCr  OldTown  Edwards  Somerst  Gilbert  NridgHt  \
# 0      CollgCr      0        1        0        0        0        0        0
# 1      Veenker      0        0        0        0        0        0        0
# 2      CollgCr      0        1        0        0        0        0        0
# 3      Crawfor      0        0        0        0        0        0        0
# 4      NoRidge      0        0        0        0        0        0        0
# 5      Mitchel      0        0        0        0        0        0        0
# 6      Somerst      0        0        0        0        1        0        0
# 7       NWAmes      0        0        0        0        0        0        0
# 8      OldTown      0        0        1        0        0        0        0
# 9      BrkSide      0        0        0        0        0        0        0
#
#    Sawyer  NWAmes  SawyerW
# 0       0       0        0
# 1       0       0        0
# 2       0       0        0
# ...

# %%
#function to create dummy features 
def one_hot_encoding(dataframe,feature,top_x_labels):
    for label in top_x_labels:
        new_df[feature +"_ "+ label]= np.where(new_df[feature]==label, 1, 0)

# %%
#encode for feature "Neighborhood"
one_hot_encoding(new_df,'Neighborhood',top_10)
new_df.head(50)
# Out:
#    MSZoning Street Alley LotShape LandContour Utilities LotConfig LandSlope  \
# 0        RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1        RL   Pave   NaN      Reg         Lvl    AllPub       FR2       Gtl
# 2        RL   Pave   NaN      IR1         Lvl    AllPub    Inside       Gtl
# 3        RL   Pave   NaN      IR1         Lvl    AllPub    Corner       Gtl
# 4        RL   Pave   NaN      IR1         Lvl    AllPub       FR2       Gtl
# 5        RL   Pave   NaN      IR1         Lvl    AllPub    Inside       Gtl
# 6        RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 7        RL   Pave   NaN      IR1         Lvl    AllPub    Corner       Gtl
# 8        RM   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 9        RL   Pave   NaN      Reg         Lvl    AllPub    Corner       Gtl
# 10       RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# ...

# %%
new_df.shape
# Out:
# (1460, 83)
